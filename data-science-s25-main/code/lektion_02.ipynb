# %% [markdown]
# # Megatutorial 2

# %%
from pandas import read_csv

# %%
read_csv("../data/fake_profiles.csv", index_col=0)
# Out:
#     profile_pic  rel_num_numeric_char_username  words_fullname  \
# 0           yes                           0.27               0
# 1           yes                           0.00               2
# 2           yes                           0.10               2
# 3           yes                           0.00               1
# 4           yes                           0.00               2
# ..          ...                            ...             ...
# 571         yes                           0.55               1
# 572         yes                           0.38               1
# 573         yes                           0.57               2
# 574         yes                           0.57               1
# 575         yes                           0.27               1
#
#      rel_num_numeric_char_fullname name=username  description_length  \
# 0                             0.00            no                  53
# ...
